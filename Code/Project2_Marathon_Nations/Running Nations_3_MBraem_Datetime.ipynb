# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as pyplot

# %%
wmm_marathons = pd.read_excel("All_winners_marathons.xlsx")
wmm_marathons.head(10)
# Out:
#    date        m_winner m_country    m_time          f_winner f_country  \
# 0  1970    Gary Muhrcke       USA  02:31:39               NaN       NaN
# 1  1971    Norm Higgins       USA  02:22:54       Beth Bonner       USA
# 2  1972  Sheldon Karlin       USA  02:27:52      Nina Kuscsik       USA
# 3  1973     Tom Fleming       USA  02:21:55      Nina Kuscsik       USA
# 4  1974  Norbert Sander       USA  02:26:31  Kathrine Switzer       USA
# 5  1975     Tom Fleming       USA  02:19:27       Kim Merritt       USA
# 6  1976    Bill Rodgers       USA  02:10:09       Miki Gorman       USA
# 7  1977    Bill Rodgers       USA  02:11:20       Miki Gorman       USA
# 8  1978    Bill Rodgers       USA  02:12:12       Grete Waitz       NOR
# 9  1979    Bill Rodgers       USA  02:11:42       Grete Waitz       NOR
#
#      f_time  marathon
# 0       NaN  New York
# 1  02:55:22  New York
# 2  03:08:41  New York
# 3  02:57:08  New York
# 4  03:07:29  New York
# 5  02:46:14  New York
# ...

# %%
New_York = wmm_marathons[wmm_marathons['marathon'] == 'New York']
New_York
# Out:
#     date                   m_winner m_country    m_time  \
# 0   1970               Gary Muhrcke       USA  02:31:39
# 1   1971               Norm Higgins       USA  02:22:54
# 2   1972             Sheldon Karlin       USA  02:27:52
# 3   1973                Tom Fleming       USA  02:21:55
# 4   1974             Norbert Sander       USA  02:26:31
# 5   1975                Tom Fleming       USA  02:19:27
# 6   1976               Bill Rodgers       USA  02:10:09
# 7   1977               Bill Rodgers       USA  02:11:20
# 8   1978               Bill Rodgers       USA  02:12:12
# 9   1979               Bill Rodgers       USA  02:11:42
# 10  1980            Alberto Salazar       USA  02:09:41
# 11  1981            Alberto Salazar       USA  02:08:13
# 12  1982            Alberto Salazar       USA  02:09:29
# 13  1983                  Rod Dixon       NZL  02:08:59
# 14  1984          Orlando Pizzolato       ITA  02:14:53
# 15  1985          Orlando Pizzolato       ITA  02:11:34
# ...

# %%
New_York.shape
# Out:
# (46, 8)

# %%
New_York.dtypes
# Out:
# date         object
# m_winner     object
# m_country    object
# m_time       object
# f_winner     object
# f_country    object
# f_time       object
# marathon     object
# dtype: object

# %%
#wmm_marathons = wmm_marathons.set_index('date')
#wmm_marathons.head()

# %%
#New_York['date'] =  pd.to_datetime(New_York['date'])#, format='%Y')

# %%
New_York.dtypes
# Out:
# date         datetime64[ns]
# m_winner             object
# m_country            object
# m_time               object
# f_winner             object
# f_country            object
# f_time               object
# marathon             object
# dtype: object

# %%
#wmm_marathons
#pd.to_timedelta(df['m_time']) #---> SOMA Version 1
#df['total_time'] = df['hour'] + df['minutes'] / 60 + df['seconds'] / (60 * 60) #---> SOMA Version 1
#pd.to_timedelta(df['m_time'])(wmm_marathons['m_time'], format='%H:%M:%S').dt.time ---> Alex Version
#pd.to_datetime(df['Created Date']) #---> documents "Foundations"
#pd.to_datetime(df['Created Date']) #---> documents "Foundations"
#raw_data['Mycol'] =  pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f') #---> Stackoverflow
#New_York['m_time'] =  pd.to_timedelta(New_York['m_time'], format='%I:%M:%S') 


#from datetime import timedelta

#New_York['m_time'] =  pd.to_timedelta(New_York['m_time'], format='%I:%M:%S')

# %%
from datetime import timedelta

pd.to_timedelta(New_York['m_time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_timedelta64 (pandas/_libs/tslib.c:58322)()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.parse_timedelta_string (pandas/_libs/tslib.c:59167)()
#
# TypeError: object of type 'datetime.time' has no len()
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-79afc26cd67c> in <module>()
#       1 from datetime import timedelta
#       2
# ----> 3 pd.to_timedelta(New_York['m_time'])
#
# /usr/local/lib/python3.6/site-packages/pandas/core/tools/timedeltas.py in to_timedelta(arg, unit, box, errors)
#      74         from pandas import Series
#      75         values = _convert_listlike(arg._values, unit=unit,
# ...

# %%
#MEN | Converting | datetime
New_York.dtypes

# %%
New_York['f_time'] =  pd.to_datetime(New_York['f_time'], format='%I:%M:%S') 
New_York['f_time'].head()

# %%
#df = df.sort_values('date', ascending=True)
#plt.plot(df['date'], df['count'])
#plt.xticks(rotation='vertical')

New_York = New_York.sort_values('date', ascending=True)
plt.plot(New_York['date'], New_York['m_time'])

# %%
New_York.groupby('m_winner')['m_country'].count().sort_values(ascending=True).plot(kind='bar')

# %%
#df['date_int'] = df.date.astype(np.int64) ---> Stackoverflow
#New_York['m_time_int'] = New_York.m_time.astype(np.int64)

# %%
#NEW YORK | Countries | Men – Women

fig = plt.figure()
ax = fig.add_subplot(121) # hoch/runter
ax2 = fig.add_subplot(122) # seitlich
New_York.groupby('m_country')['m_winner'].count().sort_values(ascending=True).plot(title='Men', color='#81D8D0', kind='barh', x='m_winner', ax=ax, y='m_country', figsize=(15,7))
New_York.groupby('f_country')['f_winner'].count().sort_values(ascending=True).plot(title='Women', color='#5B9EFF' ,kind='barh', x='f_winner', ax=ax2, y='m_country', figsize=(15,7))

# %%
#BOSTON | Countries | Men – Women
fig = plt.figure()
ax = fig.add_subplot(121) # hoch/runter
ax2 = fig.add_subplot(122) # seitlich
Boston.groupby('m_country')['m_winner'].count().sort_values(ascending=True).plot(title='Men', color='#81D8D0', kind='barh', x='m_winner', ax=ax, y='m_country', figsize=(15,7))
Boston.groupby('f_country')['f_winner'].count().sort_values(ascending=True).plot(title='Women', color='#5B9EFF' ,kind='barh', x='f_winner', ax=ax2, y='m_country', figsize=(15,7))

# %%
#wmm_marathons['m_time'] = pd.to_datetime(wmm_marathons.m_time)
#pd.to_datetime(wmm_marathons['m_time'])

#df['Time'] = pd.to_datetime(df.Time)
#pd.to_datetime(df['Created Date'])

#pd.to_datetime(wmm_marathons['m_time'], format='%H:%M:%S').dt.time

# %%
#wmm_marathons.groupby('marathon')['boston_m_winner'].count().sort_values(ascending=True).plot(color='#81D8D0', figsize=(10,5), kind='barh')#df_Boston_marathon.groupby('boston_f_country').value_counts().plot(color='#5B9EFF', figsize=(6,20), kind='barh', ax=ax, position=1)
#wmm_marathons.groupby(['marathon'] == New York).head()
