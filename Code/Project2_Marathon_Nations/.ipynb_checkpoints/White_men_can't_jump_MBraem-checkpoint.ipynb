# %% [markdown]
# >http://www.olympische-flamme.de/web_files/docs/nation_abbs.html
# http://www.avg-seco.admin.ch/WebVerzeichnis/bilder/Laendertabelle_D.pdf

# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as pyplot

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
wmm_marathons = pd.read_csv("All_winners_marathons.csv")
wmm_marathons
# Out:
#      date                          m_winner m_country    m_time  \
# 0    1970                      Gary Muhrcke       USA  02:31:39
# 1    1971                      Norm Higgins       USA  02:22:54
# 2    1972                    Sheldon Karlin       USA  02:27:52
# 3    1973                       Tom Fleming       USA  02:21:55
# 4    1974                    Norbert Sander       USA  02:26:31
# 5    1975                       Tom Fleming       USA  02:19:27
# 6    1976                      Bill Rodgers       USA  02:10:09
# 7    1977                      Bill Rodgers       USA  02:11:20
# 8    1978                      Bill Rodgers       USA  02:12:12
# 9    1979                      Bill Rodgers       USA  02:11:42
# 10   1980                   Alberto Salazar       USA  02:09:41
# 11   1981                   Alberto Salazar       USA  02:08:13
# 12   1982                   Alberto Salazar       USA  02:09:29
# 13   1983                         Rod Dixon       NZL  02:08:59
# 14   1984                 Orlando Pizzolato       ITA  02:14:53
# 15   1985                 Orlando Pizzolato       ITA  02:11:34
# 16   1986                       Gianni Poli       ITA  02:11:06
# 17   1987                   Ibrahim Hussein       KEN  02:11:01
# 18   1988                       Steve Jones       GBR  02:08:20
# 19   1989                      Juma Ikangaa       TAN  02:08:01
# 20   1990                 Douglas Wakiihuri       KEN  02:12:39
# 21   1991                   Salvador García       MEX  02:09:28
# 22   1992                      Willie Mtolo       RSA  02:09:29
# 23   1993                   Andrés Espinosa       MEX  02:10:04
# 24   1994                      Germán Silva       ITA  02:11:21
# 25   1995                      Germán Silva       ITA  02:11:00
# 26   1996                     Giacomo Leone       ITA  02:09:54
# 27   1997                        John Kagwe       KEN  02:08:12
# 28   1998                        John Kagwe       KEN  02:08:45
# 29   1999                     Joseph Chebet       KEN  02:09:14
# ..    ...                               ...       ...       ...
# 269  1999       Abdelkader El Mouaziz (MAR)       MAR  02:07:57
# 270  2000                 António Pinto -3-       POR  02:06:36
# 271  2001         Abdelkader El Mouaziz -2-       MAR  02:07:11
# 272  2002           Khalid Khannouchi (USA)       USA  02:05:38
# 273  2003             Gezahegne Abera (ETH)       ETH  02:07:56
# 274  2004                 Evans Rutto (KEN)       KEN  02:06:18
# 275  2005           Martin Kiptoo Lel (KEN)       KEN  02:07:26
# 276  2006                  Felix Limo (KEN)       KEN  02:06:39
# 277  2007             Martin Kiptoo Lel -2-       KEN  02:07:41
# 278  2008             Martin Kiptoo Lel -3-       KEN  02:05:15
# 279  2009        Samuel Kamau Wanjiru (KEN)       KEN  02:05:10
# 280  2010               Tsegay Kebede (ETH)       ETH  02:05:19
# 281  2011  Emmanuel Kipchirchir Mutai (KEN)       KEN  02:04:40
# 282  2012              Wilson Kipsang (KEN)       KEN  02:04:44
# 283  2013                 Tsegay Kebede -2-       ETH  02:06:04
# 284  2014                Wilson Kipsang -2-       KEN  02:04:29
# 285  2015              Eliud Kipchoge (KEN)       KEN  02:04:42
# 286  2016                Eliud Kipchoge -2-       KEN  02:03:05
# 287  2017              Daniel Wanjiru (KEN)       KEN  02:05:48
# 288  2007                     Daniel Njenga       KEN  02:09:45
# 289  2008                    Viktor Röthlin       SUI  02:07:23
# 290  2009                     Salim Kipsang       KEN  02:10:27
# 291  2010                 Masakazu Fujiwara       JPN  02:12:19
# 292  2011                    Hailu Mekonnen       ETH  02:07:35
# 293  2012                   Michael Kipyego       KEN  02:07:37
# 294  2013                    Dennis Kimetto       KEN  02:06:50
# 295  2014                    Dickson Chumba       KEN  02:05:42
# 296  2015                  Endeshaw Negesse       ETH  02:06:00
# 297  2016                     Feyisa Lilesa       ETH  02:06:56
# 298  2017                    Wilson Kipsang       KEN  02:03:58
#
#                             f_winner f_country    f_time  marathon
# 0                                NaN       NaN       NaN  New York
# 1                        Beth Bonner       USA  02:55:22  New York
# 2                       Nina Kuscsik       USA  03:08:41  New York
# 3                       Nina Kuscsik       USA  02:57:08  New York
# 4                   Kathrine Switzer       USA  03:07:29  New York
# 5                        Kim Merritt       USA  02:46:14  New York
# 6                        Miki Gorman       USA  02:39:11  New York
# 7                        Miki Gorman       USA  02:43:10  New York
# 8                        Grete Waitz       NOR  02:32:30  New York
# 9                        Grete Waitz       NOR  02:27:33  New York
# 10                       Grete Waitz       NOR  02:25:42  New York
# 11                       Allison Roe       NZL  02:25:29  New York
# 12                       Grete Waitz       NOR  02:27:14  New York
# 13                       Grete Waitz       NOR  02:27:00  New York
# 14                       Grete Waitz       NOR  02:29:30  New York
# 15                       Grete Waitz       NOR  02:28:34  New York
# 16                       Grete Waitz       NOR  02:28:06  New York
# 17                   Priscilla Welch       GBR  02:30:17  New York
# 18                       Grete Waitz       NOR  02:28:07  New York
# 19                Ingrid Kristiansen       NOR  02:25:30  New York
# 20                      Wanda Panfil       POL  02:30:45  New York
# 21                      Liz McColgan       GBR  02:27:32  New York
# 22               Lisa Martin-Ondieki       AUS  02:24:40  New York
# 23                        Uta Pippig       GER  02:26:24  New York
# 24                     Tegla Loroupe       KEN  02:27:37  New York
# 25                     Tegla Loroupe       KEN  02:28:06  New York
# 26                      Anuța Cătună       ROU  02:28:18  New York
# 27            Franziska Rochat-Moser       SUI  02:28:43  New York
# 28                   Franca Fiacconi       ITA  02:25:17  New York
# 29                 Adriana Fernández       MEX  02:25:06  New York
# ..                               ...       ...       ...       ...
# 269             Joyce Chepchumba -2-       KEN  02:23:22    London
# 270              Tegla Loroupe (KEN)       KEN  02:24:33    London
# 271               Derartu Tulu (ETH)       ETH  02:23:57    London
# 272            Paula Radcliffe (GBR)       GBR  02:18:56    London
# 273              Paula Radcliffe -2-       KEN  02:15:25    London
# 274             Margaret Okayo (KEN)       KEN  02:22:35    London
# 275              Paula Radcliffe -3-       GBR  02:17:42    London
# 276               Deena Kastor (USA)       USA  02:19:36    London
# 277               Zhou Chunxiu (CHN)       CHN  02:20:38    London
# 278            Irina Mikitenko (GER)       GER  02:24:14    London
# 279              Irina Mikitenko -2-       GER  02:22:11    London
# 280           Aselefech Mergia (ETH)       ETH  02:22:38    London
# 281     Mary Jepkosgei Keitany (KEN)       KEN  02:19:19    London
# 282       Mary Jepkosgei Keitany -2-       KEN  02:18:37    London
# 283             Priscah Jeptoo (KEN)       KEN  02:20:15    London
# 284  Edna Ngeringwony Kiplagat (KEN)       KEN  02:20:21    London
# 285                Tigist Tufa (ETH)       ETH  02:23:21    London
# 286             Jemima Sumgong (KEN)       KEN  02:22:58    London
# 287       Mary Jepkosgei Keitany -3-       KEN  02:17:01    London
# 288                     Hitomi Niiya       JPN  02:31:02     Tokio
# 289                   Claudia Dreher       GER  02:35:35     Tokio
# 290                  Mizuho Nasukawa       JPN  02:25:38     Tokio
# 291             Alevtina Biktimirova       RUS  02:34:39     Tokio
# 292               Noriko Higuchi [8]       JPN  02:28:49     Tokio
# 293                   Atsede Habtamu       ETH  02:25:28     Tokio
# 294                     Aberu Kebede       ETH  02:25:34     Tokio
# 295                    Tirfi Tsegaye       ETH  02:22:23     Tokio
# 296                   Birhane Dibaba       ETH  02:23:15     Tokio
# 297                     Helah Kiprop       KEN  02:21:27     Tokio
# 298               Sarah Chepchirchir       KEN  02:19:47     Tokio
#
# [299 rows x 8 columns]

# %%
New_York = wmm_marathons[wmm_marathons['marathon'] == 'New York']
New_York.head()#.loc[100]
# Out:
#    date        m_winner m_country    m_time          f_winner f_country  \
# 0  1970    Gary Muhrcke       USA  02:31:39               NaN       NaN
# 1  1971    Norm Higgins       USA  02:22:54       Beth Bonner       USA
# 2  1972  Sheldon Karlin       USA  02:27:52      Nina Kuscsik       USA
# 3  1973     Tom Fleming       USA  02:21:55      Nina Kuscsik       USA
# 4  1974  Norbert Sander       USA  02:26:31  Kathrine Switzer       USA
#
#      f_time  marathon
# 0       NaN  New York
# 1  02:55:22  New York
# 2  03:08:41  New York
# 3  02:57:08  New York
# 4  03:07:29  New York

# %%
New_York.m_country.value_counts()
# Out:
# USA    14
# KEN    13
# ITA     6
# MEX     2
# ETH     2
# BRA     2
# RSA     2
# ERI     1
# MAR     1
# NZL     1
# GBR     1
# TAN     1
# Name: m_country, dtype: int64

# %%
New_York['nothing'] = 4
New_York.set_index("date").plot(color="black", kind="bar", width=1.0, figsize=(20,4))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
New_York.head()
# Out:
#    date        m_winner m_country    m_time          f_winner f_country  \
# 0  1970    Gary Muhrcke       USA  02:31:39               NaN       NaN
# 1  1971    Norm Higgins       USA  02:22:54       Beth Bonner       USA
# 2  1972  Sheldon Karlin       USA  02:27:52      Nina Kuscsik       USA
# 3  1973     Tom Fleming       USA  02:21:55      Nina Kuscsik       USA
# 4  1974  Norbert Sander       USA  02:26:31  Kathrine Switzer       USA
#
#      f_time  marathon  nothing
# 0       NaN  New York        4
# 1  02:55:22  New York        4
# 2  03:08:41  New York        4
# 3  02:57:08  New York        4
# 4  03:07:29  New York        4

# %%
colormap = {
    'USA': '#81D8D0',
    'KEN': '#1D302F',
    'ITA': '#5B9EFF',
    'MEX': '#81D8D0',
    'ETH': '#1D302F',
    'BRA': '#FF6953',
    'RSA': '#1D302F',
    'ERI': '#1D302F',
    'MAR': '#1D302F',
    'NZL': '#FFF93C',
    'GBR': '#5B9EFF',
    'TAN': '#1D302F'
}
colors = New_York.m_country.apply(lambda country: colormap[country])

New_York['nothing'] = 4
New_York.set_index("date").plot(color=[colors], kind="bar", figsize=(20,3), width=1.0, linewidth=0, legend=False)

#plt.savefig("New_York.pdf")

# %%
#COLORCODES

#USA
#KEN || Kenya
#ITA || Italy 
#MEX || Mexico 
#ETH || Ethopia
#RSA || South Africa
#NZL || New Zealand
#ERI || Eritrea
#MAR || Marocco
#GBR || Great Britain 
#BRA || Brasil
#TAN || Tanzania

#Continents COLOR CODE
#1D302F (Africa -------> turquoise)
#FFC153 (Asia -------> orange) 
#5B9EFF (Europa -------> blue) 
#81D8D0 (North America -------> turquoise)  
#FFF93C (Oceanien -------> yellow) 
#FF6953 (South Amercia -------> red)

# %%
London = wmm_marathons[wmm_marathons['marathon'] == 'London']
London.head(2)
# Out:
#      date          m_winner m_country    m_time           f_winner f_country  \
# 251  1981   \nInge Simonsen       NOR  02:11:48  Joyce Smith (GBR)       GBR
# 252  1982  Hugh Jones (GBR)       GBR  02:09:24    Joyce Smith -2-       GBR
#
#        f_time marathon
# 251  02:29:57   London
# 252  02:29:43   London

# %%
London.m_country.value_counts()
# Out:
# KEN    13
# GBR     8
# ETH     3
# POR     3
# MAR     2
# JPN     2
# RUS     1
# DEN     1
# MEX     1
# ESP     1
# USA     1
# NOR     1
# Name: m_country, dtype: int64

# %%
colormap = {
    'KEN': '#1D302F',
    'GBR': '#5B9EFF',
    'ETH': '#1D302F',
    'POR': '#5B9EFF',
    'MAR': '#1D302F',
    'JPN': '#FFC153',
    'RUS': '#FFC153',
    'DEN': '#5B9EFF',
    'MEX': '#81D8D0',
    'ESP': '#5B9EFF',
    'USA': '#81D8D0',
    'NOR': '#5B9EFF'
}

colors = London.m_country.apply(lambda country: colormap[country])

London['nothing'] = 4
London.set_index("date").plot(color=[colors], kind="bar", figsize=(20,3), width=1.0, linewidth=0, legend=False)

#plt.savefig("New_York.pdf")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Chicago = wmm_marathons[wmm_marathons['marathon'] == 'Chicago']
Chicago.head(2)
# Out:
#      date              m_winner m_country    m_time                 f_winner  \
# 211  1977     Dan Cloeter (USA)       USA  02:17:52  Dorothy Doolittle (USA)
# 212  1978  Mark Stanforth (USA)       USA  02:19:20       Lynae Larson (USA)
#
#     f_country    f_time marathon
# 211       USA  02:50:47  Chicago
# 212       USA  02:59:25  Chicago

# %%
Chicago.m_country.value_counts()
# Out:
# KEN    16
# USA     6
# GBR     5
# MAR     4
# BRA     4
# MEX     2
# JPN     1
# ETH     1
# Name: m_country, dtype: int64

# %%
colormap = {
    'KEN': '#1D302F',
    'USA': '#81D8D0',
    'GBR': '#5B9EFF',
    'MAR': '#1D302F',
    'BRA': '#FF6953',
    'MEX': '#81D8D0',
    'JPN': '#FFC153',
    'ETH': '#1D302F',
}
colors = Chicago.m_country.apply(lambda country: colormap[country])

Chicago['nothing'] = 4
Chicago.set_index("date").plot(color=[colors], kind="bar", figsize=(20,3), width=1.0, linewidth=0, legend=False)

#plt.savefig("New_York.pdf")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
Berlin = wmm_marathons[wmm_marathons['marathon'] == 'Berlin']
Berlin.head(2)
# Out:
#      date              m_winner m_country    m_time                 f_winner  \
# 168  1974   Günter Hallas (GER)       GER  02:44:53    Jutta von Haase (GER)
# 169  1975  Ralf Bochröder (GER)       GER  02:47:08  Kristin Bochröder (GER)
#
#     f_country    f_time marathon
# 168       GER  03:22:01   Berlin
# 169       GER  03:59:15   Berlin

# %%
Berlin = wmm_marathons[wmm_marathons['marathon'] == 'Berlin']
Berlin.head(2)
# Out:
#      date              m_winner m_country    m_time                 f_winner  \
# 168  1974   Günter Hallas (GER)       GER  02:44:53    Jutta von Haase (GER)
# 169  1975  Ralf Bochröder (GER)       GER  02:47:08  Kristin Bochröder (GER)
#
#     f_country    f_time marathon
# 168       GER  03:22:01   Berlin
# 169       GER  03:59:15   Berlin

# %%
Berlin.m_country.value_counts()
# Out:
# KEN    15
# GER     7
# ETH     5
# GBR     3
# TAN     3
# RSA     2
# DEN     1
# COL     1
# AUS     1
# ESP     1
# POR     1
# POL     1
# BEL     1
# BRA     1
# Name: m_country, dtype: int64

# %%
colormap = {
    'KEN': '#1D302F',
    'GER': '#5B9EFF',
    'ETH': '#1D302F',
    'GBR': '#5B9EFF',
    'TAN': '#1D302F',
    'RSA': '#1D302F',
    'DEN': '#5B9EFF',
    'COL': '#FF6953',
    'AUS': '#5B9EFF',
    'ESP': '#5B9EFF',
    'POR': '#5B9EFF',
    'POL': '#5B9EFF',
    'BEL': '#5B9EFF',
    'BRA': '#FF6953'
}
colors = Berlin.m_country.apply(lambda country: colormap[country])

Berlin['nothing'] = 4
Berlin.set_index("date").plot(color=[colors], kind="bar", figsize=(20,3), width=1.0, linewidth=0, legend=False)

#plt.savefig("New_York.pdf")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Boston = wmm_marathons[wmm_marathons['marathon'] == 'Boston']
Boston.head(2)
# Out:
#     date           m_winner m_country    m_time f_winner f_country f_time  \
# 46  1897  John J. McDermott       USA  02:55:10      NaN       NaN    NaN
# 47  1898   Ronald MacDonald       CAN  02:42:00      NaN       NaN    NaN
#
#    marathon
# 46   Boston
# 47   Boston

# %%
Boston.m_country.value_counts()
# Out:
# USA    44
# KEN    21
# CAN    16
# JPN     8
# FIN     7
# ETH     6
# GBR     3
# KOR     3
# GRE     2
# BEL     2
# YUG     1
# SWE     1
# IRL     1
# ITA     1
# AUS     1
# NZL     1
# GER     1
# COL     1
# GUA     1
# Name: m_country, dtype: int64

# %%
colormap = {
    'USA': '#81D8D0',
    'KEN': '#1D302F',
    'CAN': '#81D8D0',
    'JPN': '#FFC153',
    'FIN': '#5B9EFF',
    'ETH': '#1D302F',
    'GBR': '#5B9EFF',
    'KOR': '#FFC153',
    'GRE': '#5B9EFF',
    'BEL': '#5B9EFF',
    'YUG': '#5B9EFF',
    'SWE': '#5B9EFF',
    'IRL': '#5B9EFF',
    'ITA': '#5B9EFF',
    'AUS': '#5B9EFF',
    'NZL': '#FFF93C'
    'GER': '#5B9EFF',
    'COL': '#FF6953',
    'GUA': '#81D8D0'
}
colors = Berlin.m_country.apply(lambda country: colormap[country])

Berlin['nothing'] = 4
Berlin.set_index("date").plot(color=[colors], kind="bar", figsize=(20,3), width=1.0, linewidth=0, legend=False)

#plt.savefig("New_York.pdf")

# %%
'KEN': '#1D302F',
    'GER': '#5B9EFF',
    'ETH': '#1D302F',
    'GBR': '#5B9EFF',
    'TAN': '#1D302F',
    'RSA': '#1D302F',
    'DEN': '#5B9EFF',
    'COL': '#FF6953',
    'AUS': '#5B9EFF',
    'ESP': '#5B9EFF',
    'POR': '#5B9EFF',
    'POL': '#5B9EFF',
    'BEL': '#5B9EFF',
    'BRA': '#FF6953',
    'KEN': '#1D302F',
    'USA': '#81D8D0',
    'GBR': '#5B9EFF',
    'MAR': '#1D302F',
    'BRA': '#FF6953',
    'MEX': '#81D8D0',
    'JPN': '#FFC153',
    'ETH': '#1D302F',
    'NZL': '#FFF93C'
}
