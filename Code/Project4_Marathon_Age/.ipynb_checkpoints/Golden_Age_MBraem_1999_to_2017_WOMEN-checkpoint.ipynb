# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np


import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as pyplot

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
Top_Women = pd.read_csv("Women_TopTen_1999-2017.csv")

# %%
#Top Ten | all women
Top_Women.head()
# Out:
#    RANK      MARK        COMPETITOR   DOB  NAT POS       VENUE  DATE1  DATE2
# 0     1  02:22:12     Eri YAMAGUGHI  1973  JPN   1       Tokyo   1999   1999
# 1     2  02:23:22  Joyce CHEPCHUMBA  1970  KEN   1      London   1999   1999
# 2     3  02:23:24       Lidia SIMON  1973  ROU   1       Osaka   1999   1999
# 3     4  02:23:25       Fatuma ROBA  1973  ETH   1  Boston, MA   1999   1999
# 4     5  02:23:58   Marleen RENDERS  1968  BEL   2      Berlin   1999   1999

# %%
Top_Women = Top_Women.set_index('DATE2')
Top_Women.head()
# Out:
#        RANK      MARK        COMPETITOR   DOB  NAT POS       VENUE  DATE1
# DATE2
# 1999      1  02:22:12     Eri YAMAGUGHI  1973  JPN   1       Tokyo   1999
# 1999      2  02:23:22  Joyce CHEPCHUMBA  1970  KEN   1      London   1999
# 1999      3  02:23:24       Lidia SIMON  1973  ROU   1       Osaka   1999
# 1999      4  02:23:25       Fatuma ROBA  1973  ETH   1  Boston, MA   1999
# 1999      5  02:23:58   Marleen RENDERS  1968  BEL   2      Berlin   1999

# %%
Top_Women.shape
# Out:
# (190, 8)

# %%
Top_Women.dtypes
# Out:
# RANK           int64
# MARK          object
# COMPETITOR    object
# DOB            int64
# NAT           object
# POS           object
# VENUE         object
# DATE1          int64
# dtype: object

# %% [markdown]
# # Creating a new Dataframe (incl. 3 new colomns)

# %% [markdown]
# New colomns: Difference | 30plus | 30minus

# %%
Top_Women['Difference'] = Top_Women['DATE1']-Top_Women['DOB']

# %%
Top_Women#.head(3)
# Out:
#        RANK      MARK                  COMPETITOR   DOB  NAT  POS  \
# DATE2
# 1999      1  02:22:12               Eri YAMAGUGHI  1973  JPN    1
# 1999      2  02:23:22            Joyce CHEPCHUMBA  1970  KEN    1
# 1999      3  02:23:24                 Lidia SIMON  1973  ROU    1
# 1999      4  02:23:25                 Fatuma ROBA  1973  ETH    1
# 1999      5  02:23:58             Marleen RENDERS  1968  BEL    2
# 1999      6  02:24:06           Adriana FERNÁNDEZ  1971  MEX    2
# 1999      7  02:24:35         Katrin DÖRRE-HEINIG  1961  GER    1
# 1999      8  02:25:09       Maria Manuela MACHADO  1963  POR    3
# 1999      9  02:25:40        Esther Wanjiru MAINA  1977  KEN    3
# 1999     10  02:25:52              Nicole CARROLL  1972  AUS    4
# 2000      1  02:21:33           Catherine NDEREBA  1972  KEN    1
# 2000      2  02:22:19             Naoko TAKAHASHI  1972  JPN    1
# 2000      3  02:22:54                 Lidia SIMON  1973  ROU    1
# 2000      4  02:22:56             Harumi HIROYAMA  1968  JPN    2
# 2000      5  02:23:31        Esther Wanjiru MAINA  1977  KEN    3
# 2000      6  02:23:43             Marleen RENDERS  1968  BEL    1
# 2000      7  02:24:02            Joyce CHEPCHUMBA  1970  KEN    1
# 2000      8  02:24:36                  Reiko TOSA  1976  JPN    2
# 2000      9  02:24:47              Elfenesh ALEMU  1975  ETH    4
# 2000     10  02:25:14                Kayoko OBATA  1971  JPN    5
# 2001      1  02:23:11                 Yoko SHIBUI  1979  JPN    1
# 2001      2  02:24:04          Svetlana ZAKHAROVA  1970  RUS    2
# 2001      3  02:25:29             Irina TIMOFEEVA  1970  RUS    2
# 2001      4  02:26:10               Tegla LOROUPE  1973  KEN    8
# 2001      5  02:26:33             Maura VICECONTE  1967  ITA    1
# 2001      6  02:26:33                 Yoko SHIBUI  1979  JPN    4
# 2001      7  02:26:58                Deena KASTOR  1973  USA    7
# 2001      8  02:27:22             Mayumi ICHIKAWA  1967  JPN    7
# 2001      9  02:27:56             Lornah KIPLAGAT  1974  KEN    4
# 2001     10  02:28:03               Tegla LOROUPE  1973  KEN    2
# ...     ...       ...                         ...   ...  ...  ...
# 2015      1  02:19:25      Gladys Cherono KIPRONO  1983  KEN    1
# 2015      2  02:19:52                 Mare DIBABA  1989  ETH    1
# 2015      3  02:20:02            Aselefech MERGIA  1985  ETH    1
# 2015      4  02:20:21           Lucy Wangui KABUU  1984  KEN    3
# 2015      5  02:20:48                Aberu KEBEDE  1986  ETH    2
# 2015      6  02:20:59                Shure DEMISE  1996  ETH    4
# 2015      7  02:21:56                 Mulu SEBOKA  1984  ETH    6
# 2015      8  02:22:08       Eunice Jepkirui KIRWA  1981  BRN    1
# 2015      9  02:22:48                 Sairi MAEDA  1991  JPN    2
# 2015     10  02:22:51             Tadelech BEKELE  1991  ETH    7
# 2016      1  02:19:41               Tirfi TSEGAYE  1984  ETH    1
# 2016      2  02:20:45                Aberu KEBEDE  1986  ETH    1
# 2016      3  02:20:48                Amane BERISO  1991  ETH    2
# 2016      4  02:21:27        Helah Jelagat KIPROP  1985  KEN    1
# 2016      5  02:21:32     Florence Jebet KIPLAGAT  1987  KEN    1
# 2016      6  02:21:51                Amane GOBENA  1986  ETH    2
# 2016      7  02:21:54            Meselech MELKAMU  1985  ETH    1
# 2016      8  02:22:17              Kayoko FUKUSHI  1982  JPN    1
# 2016      9  02:22:36   Edna Ngeringwony KIPLAGAT  1979  KEN    3
# 2016     10  02:22:40       Eunice Jepkirui KIRWA  1984  BRN    1
# 2017      1  02:17:01      Mary Jepkosgei KEITANY  1982  KEN  1r1
# 2017      2  02:17:56             Tirunesh DIBABA  1985  ETH  2r1
# 2017      3  02:19:47          Sarah CHEPCHIRCHIR  1984  KEN    1
# 2017      4  02:20:55  Purity Cherotich RIONORIPO  1983  KEN    1
# 2017      5  02:20:59       Agnes Jeruto BARSOSIO  1983  KEN    2
# 2017      6  02:21:17       Eunice Jepkirui KIRWA  1984  BRN    1
# 2017      7  02:21:19              Berhane DIBABA  1993  ETH    2
# 2017      8  02:21:22      Flomena Cheyech DANIEL  1982  KEN    3
# 2017      9  02:21:36                   Yuka ANDO  1984  JPN    2
# 2017     10  02:21:37           Visiline JEPKESHO  1989  KEN    4
#
#                                  VENUE  DATE1  Difference
# DATE2
# 1999                             Tokyo   1999          26
# 1999                            London   1999          29
# 1999                             Osaka   1999          26
# 1999                        Boston, MA   1999          26
# 1999                            Berlin   1999          31
# 1999                            London   1999          28
# 1999                           Hamburg   1999          38
# 1999                            London   1999          36
# 1999                             Osaka   1999          22
# 1999                            London   1999          27
# 2000                       Chicago, IL   2000          28
# 2000                            Nagoya   2000          28
# 2000                             Osaka   2000          27
# 2000                             Osaka   2000          32
# 2000                             Osaka   2000          23
# 2000                             Paris   2000          32
# 2000                             Tokyo   2000          30
# 2000                            Nagoya   2000          24
# 2000                             Osaka   2000          25
# 2000                             Osaka   2000          29
# 2001                             Osaka   2001          22
# 2001                            London   2001          31
# 2001                             Tokyo   2001          31
# 2001                            London   2001          28
# 2001                             Praha   2001          34
# 2001   Edmonton (Commonwealth Stadium)   2001          22
# 2001                      New York, NY   2001          28
# 2001                            Nagoya   2001          34
# 2001                        Boston, MA   2001          27
# 2001                            Berlin   2001          28
# ...                                ...    ...         ...
# 2015                            Berlin   2015          32
# 2015                            Xiamen   2015          26
# 2015                             Dubai   2015          30
# 2015                             Dubai   2015          31
# 2015                            Berlin   2015          29
# 2015                             Dubai   2015          19
# 2015                             Dubai   2015          31
# 2015                            Nagoya   2015          34
# 2015                            Nagoya   2015          24
# 2015                             Dubai   2015          24
# 2016                             Dubai   2016          32
# 2016                            Berlin   2016          30
# 2016                             Dubai   2016          25
# 2016                             Tokyo   2016          31
# 2016                       Chicago, IL   2016          29
# 2016                             Tokyo   2016          30
# 2016                           Hamburg   2016          31
# 2016                             Osaka   2016          34
# 2016                             Tokyo   2016          37
# 2016                            Nagoya   2016          32
# 2017                            London   2017          35
# 2017                            London   2017          32
# 2017                             Tokyo   2017          33
# 2017                             Paris   2017          34
# 2017                             Paris   2017          34
# 2017                            Nagoya   2017          33
# 2017                             Tokyo   2017          24
# 2017                             Paris   2017          35
# 2017                            Nagoya   2017          33
# 2017                             Paris   2017          28
#
# [190 rows x 9 columns]

# %%
Top_Women.dtypes
# Out:
# RANK           int64
# MARK          object
# COMPETITOR    object
# DOB            int64
# NAT           object
# POS           object
# VENUE         object
# DATE1          int64
# Difference     int64
# dtype: object

# %%
colorlist
# Out:
# ['blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue']

# %%
colors = {
    True: '#1D302F',
    False: '#bcb985'
}
colorlist = [colors[x] for x in Top_Women['30plus']]

Top_Women['Difference'].plot(kind='bar', figsize=(20, 4), color=[colorlist])
plt.xlabel('Age Development from 1999 to 2016', fontsize=15)

# %%
Top_Women['Difference'].mean()
# Out:
# 28.894736842105264

# %%
Top_Women['30plus'] = Top_Women['Difference'] > 29

# %%
Top_Women['30minus'] = Top_Women['Difference'] < 30

# %%
Top_Women.head()
# Out:
#        RANK      MARK        COMPETITOR   DOB  NAT POS       VENUE  DATE1  \
# DATE2
# 1999      1  02:22:12     Eri YAMAGUGHI  1973  JPN   1       Tokyo   1999
# 1999      2  02:23:22  Joyce CHEPCHUMBA  1970  KEN   1      London   1999
# 1999      3  02:23:24       Lidia SIMON  1973  ROU   1       Osaka   1999
# 1999      4  02:23:25       Fatuma ROBA  1973  ETH   1  Boston, MA   1999
# 1999      5  02:23:58   Marleen RENDERS  1968  BEL   2      Berlin   1999
#
#        Difference  30plus  30minus
# DATE2
# 1999           26   False     True
# 1999           29   False     True
# 1999           26   False     True
# 1999           26   False     True
# 1999           31    True    False

# %%
Top_Women['30plus'].plot(kind='bar', color='#1D302F', figsize=(25,3))
Top_Women['30minus'].plot(kind='bar', color='#bcb985', figsize=(25,3))

plt.xlabel('1999', fontsize=15)
plt.savefig("Top_Women.pdf")

# %% [markdown]
# # 1999

# %%
Top_Women_1999 = Top_Women[Top_Women['DATE1'] == 1999]
Top_Women_1999
# Out:
#        RANK      MARK             COMPETITOR   DOB  NAT POS       VENUE  \
# DATE2
# 1999      1  02:22:12          Eri YAMAGUGHI  1973  JPN   1       Tokyo
# 1999      2  02:23:22       Joyce CHEPCHUMBA  1970  KEN   1      London
# 1999      3  02:23:24            Lidia SIMON  1973  ROU   1       Osaka
# 1999      4  02:23:25            Fatuma ROBA  1973  ETH   1  Boston, MA
# 1999      5  02:23:58        Marleen RENDERS  1968  BEL   2      Berlin
# 1999      6  02:24:06      Adriana FERNÁNDEZ  1971  MEX   2      London
# 1999      7  02:24:35    Katrin DÖRRE-HEINIG  1961  GER   1     Hamburg
# 1999      8  02:25:09  Maria Manuela MACHADO  1963  POR   3      London
# 1999      9  02:25:40   Esther Wanjiru MAINA  1977  KEN   3       Osaka
# 1999     10  02:25:52         Nicole CARROLL  1972  AUS   4      London
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 1999    1999          26   False     True
# 1999    1999          29   False     True
# 1999    1999          26   False     True
# 1999    1999          26   False     True
# 1999    1999          31    True    False
# 1999    1999          28   False     True
# 1999    1999          38    True    False
# 1999    1999          36    True    False
# 1999    1999          22   False     True
# 1999    1999          27   False     True

# %%
Avg_1999 = Top_Women_1999['Difference'].mean()
Avg_1999
# Out:
# 28.899999999999999

# %%
#Top_Women_1999['Difference'].sort_values()

# %%
Top_Women_1999['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_1999['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('1999', fontsize=15)
plt.savefig("Top_10_1999.pdf")

# %% [markdown]
# # 2000

# %%
Top_Women_2000 = Top_Women[Top_Women['DATE1'] == 2000]
Top_Women_2000
# Out:
#        RANK      MARK            COMPETITOR   DOB  NAT POS        VENUE  \
# DATE2
# 2000      1  02:21:33     Catherine NDEREBA  1972  KEN   1  Chicago, IL
# 2000      2  02:22:19       Naoko TAKAHASHI  1972  JPN   1       Nagoya
# 2000      3  02:22:54           Lidia SIMON  1973  ROU   1        Osaka
# 2000      4  02:22:56       Harumi HIROYAMA  1968  JPN   2        Osaka
# 2000      5  02:23:31  Esther Wanjiru MAINA  1977  KEN   3        Osaka
# 2000      6  02:23:43       Marleen RENDERS  1968  BEL   1        Paris
# 2000      7  02:24:02      Joyce CHEPCHUMBA  1970  KEN   1        Tokyo
# 2000      8  02:24:36            Reiko TOSA  1976  JPN   2       Nagoya
# 2000      9  02:24:47        Elfenesh ALEMU  1975  ETH   4        Osaka
# 2000     10  02:25:14          Kayoko OBATA  1971  JPN   5        Osaka
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2000    2000          28   False     True
# 2000    2000          28   False     True
# 2000    2000          27   False     True
# 2000    2000          32    True    False
# 2000    2000          23   False     True
# 2000    2000          32    True    False
# 2000    2000          30    True    False
# 2000    2000          24   False     True
# 2000    2000          25   False     True
# 2000    2000          29   False     True

# %%
Avg_2000 = Top_Women_2000['Difference'].mean()
Avg_2000
# Out:
# 27.800000000000001

# %%
Top_Women_2000['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2000['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2000', fontsize=15)
plt.savefig("Top_10_2000.pdf")

# %% [markdown]
# # 2001

# %%
Top_Women_2001 = Top_Women[Top_Women['DATE1'] == 2001]
Top_Women_2001
# Out:
#        RANK      MARK          COMPETITOR   DOB  NAT POS  \
# DATE2
# 2001      1  02:23:11         Yoko SHIBUI  1979  JPN   1
# 2001      2  02:24:04  Svetlana ZAKHAROVA  1970  RUS   2
# 2001      3  02:25:29     Irina TIMOFEEVA  1970  RUS   2
# 2001      4  02:26:10       Tegla LOROUPE  1973  KEN   8
# 2001      5  02:26:33     Maura VICECONTE  1967  ITA   1
# 2001      6  02:26:33         Yoko SHIBUI  1979  JPN   4
# 2001      7  02:26:58        Deena KASTOR  1973  USA   7
# 2001      8  02:27:22     Mayumi ICHIKAWA  1967  JPN   7
# 2001      9  02:27:56     Lornah KIPLAGAT  1974  KEN   4
# 2001     10  02:28:03       Tegla LOROUPE  1973  KEN   2
#
#                                  VENUE  DATE1  Difference  30plus  30minus
# DATE2
# 2001                             Osaka   2001          22   False     True
# 2001                            London   2001          31    True    False
# 2001                             Tokyo   2001          31    True    False
# 2001                            London   2001          28   False     True
# 2001                             Praha   2001          34    True    False
# 2001   Edmonton (Commonwealth Stadium)   2001          22   False     True
# 2001                      New York, NY   2001          28   False     True
# 2001                            Nagoya   2001          34    True    False
# 2001                        Boston, MA   2001          27   False     True
# 2001                            Berlin   2001          28   False     True

# %%
Avg_2001 = Top_Women_2001['Difference'].mean()
Avg_2001
# Out:
# 28.5

# %%
Top_Women_2001['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2001['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2001', fontsize=15)
plt.savefig("Top_10_2001.pdf")

# %% [markdown]
# # 2002

# %%
Top_Women_2002 = Top_Women[Top_Women['DATE1'] == 2002]
Top_Women_2002.head(3)
# Out:
#        RANK      MARK         COMPETITOR   DOB  NAT POS        VENUE  DATE1  \
# DATE2
# 2002      1  02:17:18    Paula RADCLIFFE  1973  GBR   1  Chicago, IL   2002
# 2002      2  02:19:26  Catherine NDEREBA  1972  KEN   2  Chicago, IL   2002
# 2002      3  02:20:43     Margaret OKAYO  1976  KEN   1   Boston, MA   2002
#
#        Difference  30plus  30minus
# DATE2
# 2002           29   False     True
# 2002           30    True    False
# 2002           26   False     True

# %%
Avg_2002 = Top_Women_2002['Difference'].mean()
Avg_2002
# Out:
# 28.100000000000001

# %%
Top_Women_2002['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2002['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2002', fontsize=15)
plt.savefig("Top_10_2002.pdf")

# %% [markdown]
# # 2003

# %%
Top_Women_2003 = Top_Women[Top_Women['DATE1'] == 2003]
Top_Women_2003.head(3)
# Out:
#        RANK      MARK         COMPETITOR   DOB  NAT POS    VENUE  DATE1  \
# DATE2
# 2003      1  02:15:25    Paula RADCLIFFE  1973  GBR   1   London   2003
# 2003      2  02:19:39        Yingjie SUN  1979  CHN   1  Beijing   2003
# 2003      3  02:19:55  Catherine NDEREBA  1972  KEN   2   London   2003
#
#        Difference  30plus  30minus
# DATE2
# 2003           30    True    False
# 2003           24   False     True
# 2003           31    True    False

# %%
Avg_2003 = Top_Women_2003['Difference'].mean()
Avg_2003
# Out:
# 27.899999999999999

# %%
Top_Women_2003['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2003['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2003', fontsize=15)
plt.savefig("Top_10_2003.pdf")

# %%
Top_Women_2003['30plus'].sum()
# Out:
# 4

# %% [markdown]
# # 2004

# %%
Top_Women_2004 = Top_Women[Top_Women['DATE1'] == 2004]
Top_Women_2004.head(3)
# Out:
#        RANK      MARK       COMPETITOR   DOB  NAT POS         VENUE  DATE1  \
# DATE2
# 2004      1  02:19:41      Yoko SHIBUI  1979  JPN   1        Berlin   2004
# 2004      2  02:22:35   Margaret OKAYO  1976  KEN   1        London   2004
# 2004      3  02:23:10  Paula RADCLIFFE  1973  GBR   1  New York, NY   2004
#
#        Difference  30plus  30minus
# DATE2
# 2004           25   False     True
# 2004           28   False     True
# 2004           31    True    False

# %%
Avg_2004 = Top_Women_2003['Difference'].mean()
Avg_2004
# Out:
# 27.899999999999999

# %%
Top_Women_2004['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2004['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2004', fontsize=15)
plt.savefig("Top_10_2004.pdf")

# %%
Top_Women_2004['30plus'].sum()
# Out:
# 2

# %% [markdown]
# # 2005

# %%
Top_Women_2005 = Top_Women[Top_Women['DATE1'] == 2005]
Top_Women_2005.head(3)
# Out:
#        RANK      MARK       COMPETITOR   DOB  NAT POS    VENUE  DATE1  \
# DATE2
# 2005      1  02:17:42  Paula RADCLIFFE  1973  GBR   1   London   2005
# 2005      2  02:19:12   Mizuki NOGUCHI  1978  JPN   1   Berlin   2005
# 2005      3  02:21:01      Yingjie SUN  1979  CHN   1  Beijing   2005
#
#        Difference  30plus  30minus
# DATE2
# 2005           32    True    False
# 2005           27   False     True
# 2005           26   False     True

# %%
Avg_2005 = Top_Women_2005['Difference'].mean()
Avg_2005
# Out:
# 30.399999999999999

# %%
Top_Women_2005['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2005['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2005', fontsize=15)
plt.savefig("Top_10_2005.pdf")

# %%
Top_Women_2005['30plus'].sum()
# Out:
# 6

# %% [markdown]
# # 2006

# %%
Top_Women_2006 = Top_Women[Top_Women['DATE1'] == 2006]
Top_Women_2006#.head(3)
# Out:
#        RANK      MARK               COMPETITOR   DOB  NAT POS        VENUE  \
# DATE2
# 2006      1  02:19:36             Deena KASTOR  1973  USA   1       London
# 2006      2  02:19:51             Chunxiu ZHOU  1978  CHN   1        Seoul
# 2006      3  02:20:42            Berhane ADERE  1973  ETH   1  Chicago, IL
# 2006      4  02:20:47        Galina BOGOMOLOVA  1977  RUS   2  Chicago, IL
# 2006      5  02:21:29         Lyudmila PETROVA  1968  RUS   2       London
# 2006      6  02:21:34                Gete WAMI  1974  ETH   1       Berlin
# 2006      7  02:21:46  Susan Chepkemei KAPKAMA  1975  KEN   3       London
# 2006      8  02:22:36            Benita WILLIS  1979  AUS   3  Chicago, IL
# 2006      9  02:22:59              Madaí PÉREZ  1980  MEX   4  Chicago, IL
# 2006     10  02:23:22      Salina Jebet KOSGEI  1976  KEN   2       Berlin
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2006    2006          33    True    False
# 2006    2006          28   False     True
# 2006    2006          33    True    False
# 2006    2006          29   False     True
# 2006    2006          38    True    False
# 2006    2006          32    True    False
# 2006    2006          31    True    False
# 2006    2006          27   False     True
# 2006    2006          26   False     True
# 2006    2006          30    True    False

# %%
Avg_2006 = Top_Women_2006['Difference'].mean()
Avg_2006
# Out:
# 30.699999999999999

# %%
Top_Women_2006['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2006['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2006', fontsize=15)
plt.savefig("Top_10_2006.pdf")

# %%
Top_Women_2006['30plus'].sum()
# Out:
# 6

# %% [markdown]
# # 2007

# %%
Top_Women_2007 = Top_Women[Top_Women['DATE1'] == 2007]
Top_Women_2007#.head(3)
# Out:
#        RANK      MARK           COMPETITOR   DOB  NAT POS              VENUE  \
# DATE2
# 2007      1  02:20:38         Chunxiu ZHOU  1978  CHN   1             London
# 2007      2  02:21:37       Mizuki NOGUCHI  1978  JPN   1              Tokyo
# 2007      3  02:21:45            Gete WAMI  1974  ETH   2             London
# 2007      4  02:23:09      Paula RADCLIFFE  1973  GBR   1  New York City, NY
# 2007      5  02:23:12            Yanan WEI  1981  CHN   1              Seoul
# 2007      6  02:23:31  Salina Jebet KOSGEI  1976  KEN   2              Tokyo
# 2007      7  02:23:48          Yumiko HARA  1982  JPN   1              Osaka
# 2007      8  02:23:55     Constantina DITA  1970  ROU   3             London
# 2007      9  02:24:39           Mari OZAKI  1975  JPN   2              Osaka
# 2007     10  02:24:43            Yuri KANO  1978  JPN   3              Osaka
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2007    2007          29   False     True
# 2007    2007          29   False     True
# 2007    2007          33    True    False
# 2007    2007          34    True    False
# 2007    2007          26   False     True
# 2007    2007          31    True    False
# 2007    2007          25   False     True
# 2007    2007          37    True    False
# 2007    2007          32    True    False
# 2007    2007          29   False     True

# %%
Avg_2007 = Top_Women_2007['Difference'].mean()
Avg_2007
# Out:
# 30.5

# %%
Top_Women_2007['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2007['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2007', fontsize=15)
plt.savefig("Top_10_2007.pdf")

# %%
Top_Women_2007['30plus'].sum()
# Out:
# 5

# %% [markdown]
# # 2008

# %%
Top_Women_2008 = Top_Women[Top_Women['DATE1'] == 2008]
Top_Women_2008#.head(3)
# Out:
#        RANK      MARK         COMPETITOR   DOB  NAT POS              VENUE  \
# DATE2
# 2008      1  02:19:19    Irina MIKITENKO  1972  GER   1             Berlin
# 2008      2  02:21:31        Askale TAFA  1984  ETH   2             Berlin
# 2008      3  02:22:38     Yingying ZHANG  1990  CHN   1             Xiamen
# 2008      4  02:22:42      Berhane ADERE  1973  ETH   1              Dubai
# 2008      5  02:22:53  Galina BOGOMOLOVA  1977  RUS   1               Roma
# 2008      6  02:23:09    Bezunesh BEKELE  1983  ETH   2              Dubai
# 2008      7  02:23:27            Xue BAI  1988  CHN   2             Xiamen
# 2008      8  02:23:30      Yoshimi OZAKI  1981  JPN   1              Tokyo
# 2008      9  02:23:56    Paula RADCLIFFE  1973  GBR   1  New York City, NY
# 2008     10  02:24:14    Irina TIMOFEEVA  1970  RUS   1            Hamburg
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2008    2008          36    True    False
# 2008    2008          24   False     True
# 2008    2008          18   False     True
# 2008    2008          35    True    False
# 2008    2008          31    True    False
# 2008    2008          25   False     True
# 2008    2008          20   False     True
# 2008    2008          27   False     True
# 2008    2008          35    True    False
# 2008    2008          38    True    False

# %%
Avg_2008 = Top_Women_2008['Difference'].mean()
Avg_2008
# Out:
# 28.899999999999999

# %%
Top_Women_2008['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2008['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2008', fontsize=15)
plt.savefig("Top_10_2008.pdf")

# %%
Top_Women_2008['30plus'].sum()
# Out:
# 5

# %% [markdown]
# # 2009

# %%
Top_Women_2009 = Top_Women[Top_Women['DATE1'] == 2009]
Top_Women_2009#.head(3)
# Out:
#        RANK      MARK          COMPETITOR   DOB  NAT  POS        VENUE  DATE1  \
# DATE2
# 2009      1  02:22:11     Irina MIKITENKO  1972  GER  1r1       London   2009
# 2009      2  02:23:12       Mara YAMAUCHI  1973  GBR  2r1       London   2009
# 2009      3  02:23:42         Yoko SHIBUI  1979  JPN    1        Osaka   2009
# 2009      4  02:24:02     Bezunesh BEKELE  1983  ETH    1        Dubai   2009
# 2009      5  02:24:18       Teyba ERKESSO  1982  ETH    1  Houston, TX   2009
# 2009      6  02:24:24   Liliya SHOBUKHOVA  1977  RUS  3r1       London   2009
# 2009      7  02:24:42        Atsede BAYSA  1987  ETH    1        Paris   2009
# 2009      8  02:24:47      Atsede HABTAMU  1987  ETH    1       Berlin   2009
# 2009      9  02:25:02    Aselefech MERGIA  1985  ETH    2        Paris   2009
# 2009     10  02:25:06  Svetlana ZAKHAROVA  1970  RUS  4r1       London   2009
#
#        Difference  30plus  30minus
# DATE2
# 2009           37    True    False
# 2009           36    True    False
# 2009           30    True    False
# 2009           26   False     True
# 2009           27   False     True
# 2009           32    True    False
# 2009           22   False     True
# 2009           22   False     True
# 2009           24   False     True
# 2009           39    True    False

# %%
Avg_2009 = Top_Women_2009['Difference'].mean()
Avg_2009
# Out:
# 29.5

# %%
Top_Women_2009['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2009['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2009', fontsize=15)
plt.savefig("Top_10_2009.pdf")

# %%
Top_Women_2009['30plus'].sum()
# Out:
# 5

# %% [markdown]
# # 2010

# %%
Top_Women_2010 = Top_Women[Top_Women['DATE1'] == 2010]
Top_Women_2010#.head(3)
# Out:
#        RANK      MARK                COMPETITOR   DOB  NAT  POS        VENUE  \
# DATE2
# 2010      1  02:22:04              Atsede BAYSA  1987  ETH    1        Paris
# 2010      2  02:22:38          Aselefech MERGIA  1985  ETH  1r1       London
# 2010      3  02:22:43     Sharon Jemutai CHEROP  1984  KEN    1      Toronto
# 2010      4  02:22:44             Tirfi TSEGAYE  1984  ETH    2      Toronto
# 2010      5  02:23:06           Merima MOHAMMED  1992  ETH    3      Toronto
# 2010      6  02:23:17           Bezunesh BEKELE  1983  ETH  2r1       London
# 2010      7  02:23:25  Caroline Cheptanui KILEL  1981  KEN    1    Frankfurt
# 2010      8  02:23:44                 Dire TUNE  1985  ETH    2    Frankfurt
# 2010      9  02:23:53             Teyba ERKESSO  1982  ETH    1  Houston, TX
# 2010     10  02:23:58              Aberu KEBEDE  1986  ETH    1       Berlin
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2010    2010          23   False     True
# 2010    2010          25   False     True
# 2010    2010          26   False     True
# 2010    2010          26   False     True
# 2010    2010          18   False     True
# 2010    2010          27   False     True
# 2010    2010          29   False     True
# 2010    2010          25   False     True
# 2010    2010          28   False     True
# 2010    2010          24   False     True

# %%
Avg_2010 = Top_Women_2010['Difference'].mean()
Avg_2010
# Out:
# 25.100000000000001

# %%
Top_Women_2010['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2010['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2010', fontsize=15)
plt.savefig("Top_10_2010.pdf")

# %%
Top_Women_2010['30plus'].sum()
# Out:
# 0

# %% [markdown]
# # 2011

# %%
Top_Women_2011 = Top_Women[Top_Women['DATE1'] == 2011]
Top_Women_2011#.head(3)
# Out:
#        RANK      MARK                 COMPETITOR   DOB  NAT  POS        VENUE  \
# DATE2
# 2011      1  02:19:19     Mary Jepkosgei KEITANY  1982  KEN  1r1       London
# 2011      2  02:19:44    Florence Jebet KIPLAGAT  1987  KEN    1       Berlin
# 2011      3  02:20:46  Edna Ngeringwony KIPLAGAT  1979  KEN  2r1       London
# 2011      4  02:21:59               Mamitu DASKA  1983  ETH    1    Frankfurt
# 2011      5  02:22:08                Tiki GELANA  1987  ETH    1    Amsterdam
# 2011      6  02:22:09           Ejegayehu DIBABA  1982  ETH    1  Chicago, IL
# 2011      7  02:22:18            Irina MIKITENKO  1972  GER    2       Berlin
# 2011      8  02:22:34             Lydia CHEROMEI  1977  KEN    1        Praha
# 2011      9  02:22:43               Koren JELELA  1987  ETH    1      Toronto
# 2011     10  02:22:45           Aselefech MERGIA  1985  ETH    1        Dubai
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2011    2011          29   False     True
# 2011    2011          24   False     True
# 2011    2011          32    True    False
# 2011    2011          28   False     True
# 2011    2011          24   False     True
# 2011    2011          29   False     True
# 2011    2011          39    True    False
# 2011    2011          34    True    False
# 2011    2011          24   False     True
# 2011    2011          26   False     True

# %%
Avg_2011 = Top_Women_2011['Difference'].mean()
Avg_2011
# Out:
# 28.899999999999999

# %%
Top_Women_2011['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2011['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2011', fontsize=15)
plt.savefig("Top_10_2011.pdf")

# %%
Top_Women_2011['30plus'].sum()
# Out:
# 3

# %% [markdown]
# # 2012

# %%
Top_Women_2012 = Top_Women[Top_Women['DATE1'] == 2012]
Top_Women_2012#.head(3)
# Out:
#        RANK      MARK                 COMPETITOR   DOB  NAT  POS      VENUE  \
# DATE2
# 2012      1  02:18:37     Mary Jepkosgei KEITANY  1982  KEN  1r1     London
# 2012      2  02:18:58                Tiki GELANA  1987  ETH    1  Rotterdam
# 2012      3  02:19:31           Aselefech MERGIA  1985  ETH    1      Dubai
# 2012      4  02:19:34          Lucy Wangui KABUU  1984  KEN    2      Dubai
# 2012      5  02:19:50  Edna Ngeringwony KIPLAGAT  1979  KEN  2r1     London
# 2012      6  02:19:52                Mare DIBABA  1989  ETH    3      Dubai
# 2012      7  02:20:14             Priscah JEPTOO  1984  KEN  3r1     London
# 2012      8  02:20:30            Bezunesh BEKELE  1983  ETH    4      Dubai
# 2012      8  02:20:30               Aberu KEBEDE  1986  ETH    1     Berlin
# 2012     10  02:20:57    Florence Jebet KIPLAGAT  1987  KEN  4r1     London
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2012    2012          30    True    False
# 2012    2012          25   False     True
# 2012    2012          27   False     True
# 2012    2012          28   False     True
# 2012    2012          33    True    False
# 2012    2012          23   False     True
# 2012    2012          28   False     True
# 2012    2012          29   False     True
# 2012    2012          26   False     True
# 2012    2012          25   False     True

# %%
Avg_2012 = Top_Women_2012['Difference'].mean()
Avg_2012
# Out:
# 27.399999999999999

# %%
Top_Women_2012['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2012['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2012', fontsize=15)
plt.savefig("Top_10_2012.pdf")

# %%
Top_Women_2012['30plus'].sum()
# Out:
# 2

# %% [markdown]
# # 2013

# %%
Top_Women_2013 = Top_Women[Top_Women['DATE1'] == 2013]
Top_Women_2013#.head(3)
# Out:
#        RANK      MARK                   COMPETITOR   DOB  NAT  POS  \
# DATE2
# 2013      1  02:19:57         Rita Jeptoo SITIENEI  1981  KEN    1
# 2013      2  02:20:15               Priscah JEPTOO  1984  KEN  1r1
# 2013      3  02:20:48       Jemima Jelagat SUMGONG  1984  KEN    2
# 2013      4  02:21:06                 Feyse TADESE  1988  ETH    1
# 2013      5  02:21:13      Florence Jebet KIPLAGAT  1987  KEN    1
# 2013      6  02:21:32    Edna Ngeringwony KIPLAGAT  1979  KEN  2r1
# 2013      7  02:22:28        Sharon Jemutai CHEROP  1984  KEN    2
# 2013      8  02:22:34     Caroline Cheptanui KILEL  1981  KEN    1
# 2013      9  02:23:00  Flomena Chepchirchir CHUMBA  1981  KEN    2
# 2013     10  02:23:01               Berhane DIBABA  1993  ETH    3
#
#              VENUE  DATE1  Difference  30plus  30minus
# DATE2
# 2013   Chicago, IL   2013          32    True    False
# 2013        London   2013          29   False     True
# 2013   Chicago, IL   2013          29   False     True
# 2013         Paris   2013          25   False     True
# 2013        Berlin   2013          26   False     True
# 2013        London   2013          34    True    False
# 2013        Berlin   2013          29   False     True
# 2013     Frankfurt   2013          32    True    False
# 2013     Frankfurt   2013          32    True    False
# 2013     Frankfurt   2013          20   False     True

# %%
Avg_2013 = Top_Women_2013['Difference'].mean()
Avg_2013
# Out:
# 28.800000000000001

# %%
Top_Women_2013['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2013['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2012', fontsize=15)
plt.savefig("Top_10_2013.pdf")

# %%
Top_Women_2013['30plus'].sum()
# Out:
# 4

# %% [markdown]
# # 2014

# %%
Top_Women_2014 = Top_Women[Top_Women['DATE1'] == 2014]
Top_Women_2014#.head(3)
# Out:
#        RANK      MARK                 COMPETITOR   DOB  NAT  POS      VENUE  \
# DATE2
# 2014      1  02:20:18              Tirfi TSEGAYE  1984  ETH    1     Berlin
# 2014      2  02:20:21  Edna Ngeringwony KIPLAGAT  1979  KEN  1r1     London
# 2014      3  02:20:24    Florence Jebet KIPLAGAT  1987  KEN  2r1     London
# 2014      4  02:20:27               Feyse TADESE  1988  ETH    2     Berlin
# 2014      5  02:20:35            Tirunesh DIBABA  1985  ETH  3r1     London
# 2014      6  02:21:14           Shalane FLANAGAN  1981  USA    3     Berlin
# 2014      7  02:21:36                Mare DIBABA  1989  ETH    1     Xiamen
# 2014      8  02:21:52                Tigist TUFA  1987  ETH    1   Shanghai
# 2014      9  02:22:21               Aberu KEBEDE  1986  ETH    1  Frankfurt
# 2014     10  02:22:30             Berhane DIBABA  1993  ETH    2      Tokyo
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2014    2014          30    True    False
# 2014    2014          35    True    False
# 2014    2014          27   False     True
# 2014    2014          26   False     True
# 2014    2014          29   False     True
# 2014    2014          33    True    False
# 2014    2014          25   False     True
# 2014    2014          27   False     True
# 2014    2014          28   False     True
# 2014    2014          21   False     True

# %%
Avg_2014 = Top_Women_2014['Difference'].mean()
Avg_2014
# Out:
# 28.100000000000001

# %%
Top_Women_2014['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2014['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2014', fontsize=15)
plt.savefig("Top_10_2014.pdf")

# %%
Top_Women_2014['30plus'].sum()
# Out:
# 3

# %% [markdown]
# # 2015

# %%
Top_Women_2015 = Top_Women[Top_Women['DATE1'] == 2015]
Top_Women_2015#.head(3)
# Out:
#        RANK      MARK              COMPETITOR   DOB  NAT POS   VENUE  DATE1  \
# DATE2
# 2015      1  02:19:25  Gladys Cherono KIPRONO  1983  KEN   1  Berlin   2015
# 2015      2  02:19:52             Mare DIBABA  1989  ETH   1  Xiamen   2015
# 2015      3  02:20:02        Aselefech MERGIA  1985  ETH   1   Dubai   2015
# 2015      4  02:20:21       Lucy Wangui KABUU  1984  KEN   3   Dubai   2015
# 2015      5  02:20:48            Aberu KEBEDE  1986  ETH   2  Berlin   2015
# 2015      6  02:20:59            Shure DEMISE  1996  ETH   4   Dubai   2015
# 2015      7  02:21:56             Mulu SEBOKA  1984  ETH   6   Dubai   2015
# 2015      8  02:22:08   Eunice Jepkirui KIRWA  1981  BRN   1  Nagoya   2015
# 2015      9  02:22:48             Sairi MAEDA  1991  JPN   2  Nagoya   2015
# 2015     10  02:22:51         Tadelech BEKELE  1991  ETH   7   Dubai   2015
#
#        Difference  30plus  30minus
# DATE2
# 2015           32    True    False
# 2015           26   False     True
# 2015           30    True    False
# 2015           31    True    False
# 2015           29   False     True
# 2015           19   False     True
# 2015           31    True    False
# 2015           34    True    False
# 2015           24   False     True
# 2015           24   False     True

# %%
Avg_2015 = Top_Women_2015['Difference'].mean()
Avg_2015
# Out:
# 28.0

# %%
Top_Women_2015['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2015['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2015', fontsize=15)
plt.savefig("Top_10_2015.pdf")

# %%
Top_Women_2015['30plus'].sum()
# Out:
# 5

# %% [markdown]
# # 2016

# %%
Top_Women_2016 = Top_Women[Top_Women['DATE1'] == 2016]
Top_Women_2016#.head(3)
# Out:
#        RANK      MARK                 COMPETITOR   DOB  NAT POS        VENUE  \
# DATE2
# 2016      1  02:19:41              Tirfi TSEGAYE  1984  ETH   1        Dubai
# 2016      2  02:20:45               Aberu KEBEDE  1986  ETH   1       Berlin
# 2016      3  02:20:48               Amane BERISO  1991  ETH   2        Dubai
# 2016      4  02:21:27       Helah Jelagat KIPROP  1985  KEN   1        Tokyo
# 2016      5  02:21:32    Florence Jebet KIPLAGAT  1987  KEN   1  Chicago, IL
# 2016      6  02:21:51               Amane GOBENA  1986  ETH   2        Tokyo
# 2016      7  02:21:54           Meselech MELKAMU  1985  ETH   1      Hamburg
# 2016      8  02:22:17             Kayoko FUKUSHI  1982  JPN   1        Osaka
# 2016      9  02:22:36  Edna Ngeringwony KIPLAGAT  1979  KEN   3        Tokyo
# 2016     10  02:22:40      Eunice Jepkirui KIRWA  1984  BRN   1       Nagoya
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2016    2016          32    True    False
# 2016    2016          30    True    False
# 2016    2016          25   False     True
# 2016    2016          31    True    False
# 2016    2016          29   False     True
# 2016    2016          30    True    False
# 2016    2016          31    True    False
# 2016    2016          34    True    False
# 2016    2016          37    True    False
# 2016    2016          32    True    False

# %%
Avg_2016 = Top_Women_2016['Difference'].mean()
Avg_2016
# Out:
# 31.100000000000001

# %%
Top_Women_2016['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2016['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2016', fontsize=15)
plt.savefig("Top_10_2016.pdf")

# %%
Top_Women_2016['30plus'].sum()
# Out:
# 8

# %% [markdown]
# # 2017

# %%
Top_Women_2017 = Top_Women[Top_Women['DATE1'] == 2017]
Top_Women_2017#.head(3)
# Out:
#        RANK      MARK                  COMPETITOR   DOB  NAT  POS   VENUE  \
# DATE2
# 2017      1  02:17:01      Mary Jepkosgei KEITANY  1982  KEN  1r1  London
# 2017      2  02:17:56             Tirunesh DIBABA  1985  ETH  2r1  London
# 2017      3  02:19:47          Sarah CHEPCHIRCHIR  1984  KEN    1   Tokyo
# 2017      4  02:20:55  Purity Cherotich RIONORIPO  1983  KEN    1   Paris
# 2017      5  02:20:59       Agnes Jeruto BARSOSIO  1983  KEN    2   Paris
# 2017      6  02:21:17       Eunice Jepkirui KIRWA  1984  BRN    1  Nagoya
# 2017      7  02:21:19              Berhane DIBABA  1993  ETH    2   Tokyo
# 2017      8  02:21:22      Flomena Cheyech DANIEL  1982  KEN    3   Paris
# 2017      9  02:21:36                   Yuka ANDO  1984  JPN    2  Nagoya
# 2017     10  02:21:37           Visiline JEPKESHO  1989  KEN    4   Paris
#
#        DATE1  Difference  30plus  30minus
# DATE2
# 2017    2017          35    True    False
# 2017    2017          32    True    False
# 2017    2017          33    True    False
# 2017    2017          34    True    False
# 2017    2017          34    True    False
# 2017    2017          33    True    False
# 2017    2017          24   False     True
# 2017    2017          35    True    False
# 2017    2017          33    True    False
# 2017    2017          28   False     True

# %%
Avg_2017 = Top_Women_2017['Difference'].mean()
Avg_2017
# Out:
# 32.100000000000001

# %%
Top_Women_2017['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
Top_Women_2017['30minus'].plot(kind='bar', color='#bcb985', figsize=(5,3))
plt.xlabel('2017', fontsize=15)
plt.savefig("Top_10_2017.pdf")

# %%
Top_Women_2016['30plus'].sum()
# Out:
# 8

# %%
#Um nur die Balken über 30 auszuwählen:
Top_Women_2003['30plus'].plot(kind='bar', color='#1D302F', figsize=(5,3))
plt.xlabel('2003', over 30, fontsize=15)
# Out:
#   File "<ipython-input-93-3e911554e852>", line 3
#     plt.xlabel('2003', over 30, fontsize=15)
#                              ^
# SyntaxError: invalid syntax

# %%
# 1 row, 2 columns, and we'd like the second element.
ax1 = plt.subplot(1, 2, 1)
Top_Women_2000['30plus'].plot(kind='bar', color='#1D302F', figsize=(8, 3))
Top_Women_2000['30minus'].plot(kind='bar', color='#bcb985', figsize=(8, 3))
ax1.set_title("2000")

# 1 row, 2 columns, and we'd like the first element.
ax2 = plt.subplot(1, 2, 2)
Top_Women_2001['30plus'].plot(kind='bar', color='#1D302F', figsize=(8, 3))
Top_Women_2001['30minus'].plot(kind='bar', color='#bcb985', figsize=(8, 3))
ax2.set_title("2001")
