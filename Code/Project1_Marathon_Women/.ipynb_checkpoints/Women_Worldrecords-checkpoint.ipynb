# %% [markdown]
# Working with time | Notebook and Notes:
# http://jonathansoma.com/lede/foundations-2017/classes/working-with-time/house-sales-and-time-data/

# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np


import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as pyplot

# %%
import datetime

# %%
women_worldrecords = pd.read_csv("Frauen_Weltrekord-Entwicklung.csv")
women_worldrecords.head(20)
# Out:
#         Zeit          Name/Nation Nation                Ort    Jahr
# 0   03:40:22         Violet Percy    GBR            London   1926.0
# 1   03:37:07         Merry Lepper    USA       Culver City   1963.0
# 2   03:27:45           Dale Greig    GBR          Ryde/GBR   1964.0
# 3   03:19:33      Mildred Sampson    NZL           Auckland  1964.0
# 4   03:15:22       Maureen Wilton    CAN            Toronto  1967.0
# 5   03:07:26    Anni Pede-Erdkamp    GER      Waldniel/GER   1967.0
# 6   03:02:53      Caroline Walker    USA       Seaside/USA   1970.0
# 7   03:01:42     Elizabeth Bonner    USA      Philadelphia   1971.0
# 8   03:00:35      Sara Mae Berman    USA       Brockton/USA  1971.0
# 9   02:46:30      Adrienne Beames    AUS       Werribee/USA  1971.0
# 10  02:46:24     Chantal Langlacé    FRA  Neuf Brisach/FRA   1974.0
# 11  02:43:54    Jacqueline Hansen    USA   Culver City/ USA  1974.0
# 12  02:42:24         Liane Winter    GER             Boston  1975.0
# ...

# %%
women_worldrecords.dtypes
# Out:
# Zeit            object
# Name/Nation     object
# Nation          object
# Ort             object
# Jahr           float64
# dtype: object

# %%
women_worldrecords['Jahr']
# Out:
# 0     1926.0
# 1     1963.0
# 2     1964.0
# 3     1964.0
# 4     1967.0
# 5     1967.0
# 6     1970.0
# 7     1971.0
# 8     1971.0
# 9     1971.0
# 10    1974.0
# 11    1974.0
# 12    1975.0
# 13    1975.0
# 14    1977.0
# 15    1977.0
# 16    1978.0
# 17    1979.0
# 18    1980.0
# 19    1981.0
# 20    1983.0
# 21    1985.0
# 22    1998.0
# 23    1999.0
# 24    2001.0
# 25    2001.0
# 26    2002.0
# 27    2003.0
# 28       NaN
# 29       NaN
# Name: Jahr, dtype: float64

# %%
#women_worldrecords['Zeit'] = pd.to_datetime(women_worldrecords.Time)
#pd.to_datetime(women_worldrecords['Jahr'])
#pd.to_datetime(df.per_name).head()
#pd.to_datetime(women_worldrecords.Jahr).head()
pd.to_datetime(women_worldrecords.Jahr, format="%Y").head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2ca7b3de5790> in <module>()
#       3 #pd.to_datetime(df.per_name).head()
#       4 #pd.to_datetime(women_worldrecords.Jahr).head()
# ----> 5 pd.to_datetime(women_worldrecords.Jahr, format="%Y").head()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     507     elif isinstance(arg, ABCSeries):
#     508         from pandas import Series
# --> 509         values = _convert_listlike(arg._values, False, format)
#     510         result = Series(values, index=arg.index, name=arg.name)
#     511     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
# ...

# %%
women_worldrecords
# Out:
#                                     Zeit            Name/Nation Nation  \
# 0                               03:40:22           Violet Percy    GBR
# 1                               03:37:07           Merry Lepper    USA
# 2                               03:27:45             Dale Greig    GBR
# 3                               03:19:33        Mildred Sampson    NZL
# 4                               03:15:22         Maureen Wilton    CAN
# 5                               03:07:26      Anni Pede-Erdkamp    GER
# 6                               03:02:53        Caroline Walker    USA
# 7                               03:01:42       Elizabeth Bonner    USA
# 8                               03:00:35        Sara Mae Berman    USA
# 9                               02:46:30        Adrienne Beames    AUS
# 10                              02:46:24       Chantal Langlacé    FRA
# 11                              02:43:54      Jacqueline Hansen    USA
# ...

# %%
women_worldrecords.dtypes
# Out:
# Zeit            object
# Name/Nation     object
# Nation          object
# Ort             object
# Jahr           float64
# dtype: object

# %%
women_worldrecords.plot()
