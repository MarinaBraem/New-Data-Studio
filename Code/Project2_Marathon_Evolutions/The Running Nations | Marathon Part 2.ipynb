# %% [markdown]
# # The Running Nations

# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np


import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import matplotlib.pyplot as pyplot

# %%
df_marathon_ny = pd.read_excel("NY_Marathon_clean.xlsx")
df_marathon_ny.head(5)
# Out:
#    date                  m_winner m_country    m_time        f_winner  \
# 0  2016     Ghirmay Ghebreslassie     (ERI)  02:07:51    Mary Keitany
# 1  2015  Stanley Kipleting Biwott     (KEN)  02:10:34    Mary Keitany
# 2  2014            Wilson Kipsang     (KEN)  02:10:59    Mary Keitany
# 3  2013    Geoffrey Kiprono Mutai     (KEN)  02:08:24  Priscah Jeptoo
# 4  2012                       NaN       NaN       NaN             NaN
#
#   f_country    f_time  m_starter  f_starter  total_starter  m_finisher  \
# 0     (KEN)  02:24:26        NaN        NaN            NaN         NaN
# 1     (KEN)  02:24:25    29291.0    20944.0        50235.0     28899.0
# 2     (KEN)  02:25:07    30324.0    20572.0        50896.0     30108.0
# 3     (KEN)  02:25:07    31002.0    19738.0        50740.0     30699.0
# 4       NaN       NaN        NaN        NaN            NaN         NaN
#
#    f_finisher  total_finisher
# 0         NaN             NaN
# 1     20696.0         49595.0
# 2     20422.0         50530.0
# 3     19567.0         50266.0
# 4         NaN             NaN

# %%
df_marathon_ny = df_marathon_ny.set_index('date')
df_marathon_ny.head(20)
# Out:
#                        m_winner m_country    m_time  \
# date
# 2016      Ghirmay Ghebreslassie     (ERI)  02:07:51
# 2015   Stanley Kipleting Biwott     (KEN)  02:10:34
# 2014             Wilson Kipsang     (KEN)  02:10:59
# 2013     Geoffrey Kiprono Mutai     (KEN)  02:08:24
# 2012                        NaN       NaN       NaN
# 2011     Geoffrey Kiprono Mutai     (KEN)  02:05:06
# 2010  Gebregziabher Gebremariam     (ETH)  02:08:14
# 2009       Mebrahtom Keflezighi     (USA)  02:09:15
# 2008        Marílson dos Santos     (BRA)  02:08:43
# 2007          Martin Kiptoo Lel     (KEN)  02:09:04
# 2006        Marílson dos Santos     (BRA)  02:09:58
# 2005                Paul Tergat     (KEN)  02:09:30
# 2004           Hendrick Ramaala     (RSA)  02:09:28
# 2003          Martin Kiptoo Lel     (KEN)  02:10:30
# 2002                Rodgers Rop     (KEN)  02:08:07
# 2001              Tesfaye Jifar     (ETH)  02:07:43
# 2000      Abdelkader El Mouaziz     (MAR)  02:10:09
# 1999              Joseph Chebet     (KEN)  02:09:14
# 1998                 John Kagwe     (KEN)  02:08:45
# 1997                 John Kagwe     (KEN)  02:08:12
#
#                        f_winner f_country    f_time  m_starter  f_starter  \
# date
# 2016               Mary Keitany     (KEN)  02:24:26        NaN        NaN
# 2015               Mary Keitany     (KEN)  02:24:25    29291.0    20944.0
# 2014               Mary Keitany     (KEN)  02:25:07    30324.0    20572.0
# 2013             Priscah Jeptoo     (KEN)  02:25:07    31002.0    19738.0
# 2012                        NaN       NaN       NaN        NaN        NaN
# 2011             Firehiwot Dado     (ETH)  02:23:15    30200.0    17563.0
# 2010  Edna Ngeringwony Kiplagat     (KEN)  02:28:20    29097.0    16253.0
# 2009               Derartu Tulu     (ETH)  02:28:52    28808.0    15369.0
# 2008            Paula Radcliffe     (GBR)  02:23:56    25669.0    13163.0
# 2007            Paula Radcliffe     (GBR)  02:23:09    26525.0    12740.0
# 2006          Jeļena Prokopčuka     (LAT)  02:25:05    25890.0    12478.0
# 2005          Jeļena Prokopčuka     (LAT)  02:24:41    25279.0    12318.0
# 2004            Paula Radcliffe     (GBR)  02:23:10    25051.0    12206.0
# 2003             Margaret Okayo     (KEN)  02:22:31    23359.0    11927.0
# 2002           Joyce Chepchumba     (KEN)  02:25:56    22140.0    10209.0
# 2001             Margaret Okayo     (KEN)  02:24:21    17080.0     6977.0
# 2000           Ljudmila Petrowa     (RUS)  02:25:45    21289.0     8641.0
# 1999          Adriana Fernández     (MEX)  02:25:06    23077.0     9426.0
# 1998            Franca Fiacconi     (ITA)  02:25:17    23327.0     9071.0
# 1997     Franziska Rochat-Moser     (SUI)  02:28:43    22608.0     8792.0
#
#       total_starter  m_finisher  f_finisher  total_finisher
# date
# 2016            NaN         NaN         NaN             NaN
# 2015        50235.0     28899.0     20696.0         49595.0
# 2014        50896.0     30108.0     20422.0         50530.0
# 2013        50740.0     30699.0     19567.0         50266.0
# 2012            NaN         NaN         NaN             NaN
# 2011        47763.0     30068.0     17272.0         47340.0
# 2010        45350.0     28948.0     16155.0         45103.0
# 2009        44177.0     28485.0     15175.0         43660.0
# 2008        38832.0     25216.0     12880.0         38096.0
# 2007        39265.0     26072.0     12535.0         38607.0
# 2006        38368.0     25546.0     12320.0         37866.0
# 2005        37597.0     24795.0     12062.0         36857.0
# 2004        37257.0     24574.0     11988.0         36562.0
# 2003        35286.0     23014.0     11715.0         34729.0
# 2002        32560.0     21625.0     10209.0         31834.0
# 2001        24057.0     16811.0      6853.0         23664.0
# 2000        29930.0     21005.0      8331.0         29336.0
# 1999        32503.0     22626.0      9160.0         31786.0
# 1998        32398.0     22587.0      8952.0         31539.0
# 1997        31400.0     22014.0      8413.0         30427.0

# %%
df_marathon_ny['total_finisher'].plot(figsize=(10,5))
